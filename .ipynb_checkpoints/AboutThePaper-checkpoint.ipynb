# %% [markdown]
# ## Article: A gene-environment-induced epigenetic program initiates tumorigenesis
#
# __doi:__ https://doi.org/10.1038/s41586-020-03147-x
#
# __Author:__ Direna Alonso-Curbelo, Yu-Jui Ho, Cassandra Burdziak, Jesper L. V. Maag, John P. Morris IV, Rohit Chandwani, Hsuan-An Chen, Kaloyan M. Tsanov, Francisco M. Barriga, Wei Luan1, Nilgun Tasdemir, Geulah Livshits, Elham Azizi, Jaeyoung Chun, John E. Wilkinson, Linas Mazutis, Steven D. Leach, Richard Koche, Dana Pe’er & Scott W. Lowe

# %% [markdown]
# ### Paper Summary:
# KRAS mutation is found to be associated with pancreatic ductal adenocarcinoma (PDAC), a type of damage-associated carcinogenesis that is lethal and, unfortunately, lacks effective therapies. In their search for the mechanism of mutant KRAS induced PDAC, Alonso-Curbelo et al. revealed that a genetic change (the mutated KRAS) in combination with environmental change (tissue damage) promotes an epigenetic reprogramming that involved acinar-to-neoplasia chromatin switch in the pancreatic cells.
#
# The mechanism is illustrated in the figure below, with highlights listed in the following bullet points:
#    > ![image.png](attachment:image.png)
#    >* With KRAS mutation, injured pancreatic cells gain a PDAC-like chromatin profile, which results in neoplasia-specific transcription.
#    >* Interleukin-33 (IL-33) is the most robustly activated factor.
#    >* With protein BRD4 that can access open chromatin, which is supposed to aid in re-establish of acinar-like chromatin profile, now aids in the increased expression of IL-33.
#    >* IL-33 further promote neoplasia formation, which can then develop into PDAC
#
# Overall, this study demonstrates how gene-environment interactions can alter gene-regulatory programs to initiate tumor formation, which opens up the possibility for novel therapeutic strategies to prevent (e.g., inhibit expression of BRD4 to prevent the expression of IL-33) and detect (e.g., the target expression level of IL-33) tumors before they evolve to an advanced stage.

# %% [markdown]
# ### Result to be reproduced:
# __1. Fig 1e:__
# > Heat map representation of ATAC-seq peaks gained or lost between normal, injury, Kras * and Kras * + injury conditions. Each column represents an independent mouse. Numbers indicate the number of peaks per cluster. Reg, regenerative.
#     > ![image.png](attachment:image.png)
#     >* 67% of the ATAC gains unique to cells undergoing synchronous neoplastic transformation by the combined effects of mutant  Kras and injury (cluster N2) were retained in advanced PDAC, whereas those specific to each insult alone (for example, cluster R) were not
#
# __2. Fig 3d:__
# > Quantification of PanIN lesion area in pancreases from 6-week-old KC-shRen (n = 4) or KC-shBrd4 (n = 8) mice, or 1-year-old KC-shRen (n = 3) or KC-shBrd4 (n = 4) mice
#     > ![image-2.png](attachment:image-2.png)
#     >* In the neoplastic context, suppression of BRD4 prevented the appearance of PanIN lesions
#
# __3. Fig 3f:__
# > Top: heat map of downregulated DEGs after suppression of BRD4 in regenerative metaplasia (Csh: injury) or neoplastic transformation (KCsh: Kras* + injury) settings across the indicated conditions (as in Extended Data Fig. 4a). n = 3 shRen.713 or shBrd4.1448 mice (rows) per condition. Normal C-shRen samples show expression levels of DEGs in healthy pancreas. Black squares indicate genes that are uniquely sensitive to BRD4 suppression in cells undergoing injury-driven regenerative (left) versus neoplastic (right) transitions. See Supplementary Table 4 for list of shBrd4-sensitive genes in each context.
# >
# > Bottom: chromatin accessibility dynamics at regulatory loci of shBrd4-sensitive genes, indicated by ATAC cluster annotation
#     > ![image-3.png](attachment:image-3.png)
#     >* Consistent with the differential chromatin states observed during regenerative compared to pro-neoplastic metaplasia, the BRD4-sensitive gene expression programs in each condition were also distinct.
#     > >* In the regenerative context (Csh: injury), BRD4 suppression blunted the expression of genes linked to acinar-specific (A) clusters identified through ATAC-seq
#     > >* In the neoplastic setting (KCsh: Kras* + injury), suppression of BRD4 also eroded acinar gene expression (Extended Data Fig. 6b–d) but, in addition, impaired the activation of a larger set of genes that otherwise become selectively accessible and induced in this context (clusters N1 and N2)
#
# __4. Fig 4e:__
# > Left, UMAP (uniform manifold approximation and projection) visualization of scATAC-seq prof iles of 6, 369 BRD4-competent K ras-mutant pancreatic epithelial cells (mKate2+) isolated from Kras* and Kras* + injury tissue conditions (n = 1 mouse for each), and coloured by the indicated tissue condition.
# >
# > Right, inferred activity scores for the acinar TF NR 5A 2 and the cancer-associated TF AP-1 per individual cell are displayed in colour, showing a switch in transcription factor activity in Kras-mutant cells after tissue injury.
#     > ![image-4.png](attachment:image-4.png)
#     >* consistent with chromatin remodelling, mapping of activity scores of TFs associated with acinar differentiation (for example, NR5A2) or those that are induced by Kras mutation and/or by injury (for example, AP-1) per individual cell showed a shift in TF activities of Kras-mutant cells after tissue injury
#
# __5. Fig 4f:__
# > NR5A2 and AP-1 activity scores of Kras-mutant cells (columns) annotated by tissue condition (as in e, left)
#     > ![image-5.png](attachment:image-5.png)
#     >* those that are induced by Kras mutation and/or by injury (for example, AP-1) per individual cell showed an anticorrelation of their activity scores across single-cell epigenetic profiles
#
# __6. Fig 4g:__
# > Top-scoring pathways in GREAT gene ontology (GO) analyses of peaks that are positively or negatively correlated with the chromatin switch def ined by increasing AP-1/NR 5A 2 activity ratios across the single-cell epigenetic profiles of Kras-mutant cells shown in f.
#     > ![image-6.png](attachment:image-6.png)
#     >* Many of the neoplasia-specific chromatin-activated genes encoded membrane-bound and secreted proteins
#
# __7. Fig 5a:__
# > Effects of BRD4 suppression (shBrd4.1448 versus shRen.713, y axis) on the mRNA expression levels of the indicated cytokines or chemokines and their degree of activation in pancreatic epithelial cells during injury-facilitated neoplasia (x-axis). Factors exhibiting neoplasia-specific mRNA upregulation and ATAC gain are marked in orange.
#     > ![image-7.png](attachment:image-7.png)
#     >* Analysis of both bulk and scATAC-seq chromatin accessibility datasets consistently identified numerous peaks at the Il33 locus that were rapidly and selectively gained in Kras-mutant pancreases undergoing the injury-facilitated chromatin switch (Kras* + injury) and retained in established PDAC
#
# __8. Fig 5c:__
# > Volcano plots showing the cooperation between rIL-33 and mutant Kras in driving transcriptional reprogramming of the pancreatic epithelium, assessed by RNA-seq of mKate2+ epithelial cells isolated from Kras-wild type (C) mice treated with rIL-33 (n = 4) or vehicle (PBS; n = 5) (left), or Kras-mutant (KC) mice treated with rIL-33 (n = 4) or vehicle (Veh; PBS, n = 4) (right), 21 days after treatment.
#     > ![image-8.png](attachment:image-8.png)
#     >* examined the extent to which exogenous IL-33 could recapitulate the effects of tissue damage by treating mice expressing mutant (KC) or wild-type (C) Kras with recombinant IL-33 (rIL-33). Notably, rIL-33 mimicked the effects of injury in cooperating with mutant KRAS to activate the neoplasia-specific, BRD4-dependent gene expression program that is induced by tissue damage in the pre-malignant pancreas —including genes that are upregulated in advanced human PDAC
#
# __9. Fig 5f:__
# > Quantification of normal exocrine tissue (acinar) or metaplastic (ADM) and neoplastic (PanIN) lesion area in Kras-wild-type (left) or Kras-mutant (right) mice treated with rIL-33 or vehicle (PBS), at 21 days. Pooled data are mean ± s.e.m. n = 3, 4, 4 or 5 (from left to right) mice; P = 0.0169 for PanIN area in KC rIL-33 versus vehicle (unpaired two-tailed Student’s t-test)
#     > ![image-9.png](attachment:image-9.png)
